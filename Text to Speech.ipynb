# %% [markdown]
# ## Text to Speech (FREE) - How to Generate Your Own Voice using Python

# %%
import gtts
import playsound

text = input("enter the text you want to convert it into speech ")
sound = gtts.gTTS(text, lang="en")
sound.save("sound for text to speech.mp3")
playsound.playsound("sound for text to speech.mp3")
